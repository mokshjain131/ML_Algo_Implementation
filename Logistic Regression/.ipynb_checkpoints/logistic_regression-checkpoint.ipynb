# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ### Index
# 1. Packages
# 2. Dataset
# 3. Data Cleaning
# 4. Plotting
# 5. Data Split
# 6. Feature Scaling
# 7. Feature Engineering
# 8. Compute Regularized Cost
# 9. Gradient
# 10. Gradient Descent
# 11. Training
# 12. Testing
# 13. Scikit-Learn Implementation

# %% [markdown]
# ### Packages
# - importing `numpy` for scientific calculations
# - importing `pandas` for data handling
# - importing `matplotlib` for plotting graphs
# - importing `copy`, `math` and `os` for different operations
# - importing a logistic regression model from `scikit-learn` for comparing
